# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
dataset = pd.read_csv(r"C:\Users\Pranav\OneDrive\Desktop\Machie Learning\ds_salaries.csv")
df = pd.DataFrame(dataset)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# work_year             3755
# experience_level      3755
# employment_type       3755
# job_title             3755
# salary                3755
# salary_currency       3755
# salary_in_usd         3755
# employee_residence    3755
# remote_ratio          3755
# company_location      3755
# company_size          3755
# dtype: int64

# %%
df_cleaned=df.dropna()
print(df_cleaned)
print(df_cleaned.notnull().sum())
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
print(X)
# Out:
# [[2023 'SE' 'FT' ... 'ES' 100 'ES']
#  [2023 'MI' 'CT' ... 'US' 100 'US']
#  [2023 'MI' 'CT' ... 'US' 100 'US']
#  ...
#  [2020 'EN' 'FT' ... 'US' 100 'US']
#  [2020 'EN' 'CT' ... 'US' 100 'US']
#  [2021 'SE' 'FT' ... 'IN' 50 'IN']]

# %%
print(y)
# Out:
# ['L' 'S' 'S' ... 'S' 'L' 'L']

# %%
df1 = df.copy()
print("Before:",df1.shape)
df1.dropna(inplace=True)
print("After:",df1.shape)
# Out:
# Before: (3755, 11)
# After: (3755, 11)

# %%
X
# Out:
# array([[2023, 'SE', 'FT', ..., 'ES', 100, 'ES'],
#        [2023, 'MI', 'CT', ..., 'US', 100, 'US'],
#        [2023, 'MI', 'CT', ..., 'US', 100, 'US'],
#        ...,
#        [2020, 'EN', 'FT', ..., 'US', 100, 'US'],
#        [2020, 'EN', 'CT', ..., 'US', 100, 'US'],
#        [2021, 'SE', 'FT', ..., 'IN', 50, 'IN']], dtype=object)

# %%
df_filled=df.fillna(0)
print(df_filled)
print(df_filled.notnull().sum())
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df_replaced=df.replace('0','1')
print(df_replaced)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df_interpolated=df.interpolate()
print(df_interpolated)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
nan_mask=df.isnull()
nan_values=df[nan_mask]
print("DataFrame with NaN values:")
print(df)
print("\nDataFrame with NaN values only:")
print(nan_values)
# Out:
# DataFrame with NaN values:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
age_condition=df['salary']>40000
filtered_data=df[age_condition]
print("Filterd data based on age greater than 25")
print(filtered_data)
# Out:
# Filterd data based on age greater than 25
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# 5          2023               SE              FT         Applied Scientist
# 6          2023               SE              FT         Applied Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...
